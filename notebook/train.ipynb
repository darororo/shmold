# %%
from ultralytics import YOLO
import torch
import gc

try:
    model = YOLO("/home/eva/Documents/ITC/I5/ImageProcessing/mold_detection/shmold/runs/segment/train30/weights/best.pt") 
    
    metrics = model.val(data="../data.yaml", imgsz=640, conf=0.25)
    
    print(f"--- Benchmark Results ---")
    print(f"Precision (Quality): {metrics.results_dict['metrics/precision(B)']:.4f}")
    print(f"Recall (Completeness): {metrics.results_dict['metrics/recall(B)']:.4f}")
    print(f"mAP@50 (Overall Accuracy): {metrics.results_dict['metrics/mAP50(B)']:.4f}")
    print(f"mAP@50-95 (Strict Accuracy): {metrics.results_dict['metrics/mAP50-95(B)']:.4f}")
    
    speed = metrics.speed
    print(f"Inference Speed: {speed['inference']:.2f} ms per image")

finally:
    # Clean up GPU memory
    print("\n--- Cleaning up GPU memory ---")
    del model
    del metrics
    
    # Clear PyTorch cache
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    
    # Force garbage collection
    gc.collect()
    
    print("GPU memory cleared successfully!")
# Out:
# Ultralytics 8.3.241 🚀 Python-3.14.2 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 7840MiB)
# YOLO11s-seg summary (fused): 113 layers, 10,067,203 parameters, 0 gradients, 32.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3135.0±2036.7 MB/s, size: 80.8 KB)
# val: Scanning /home/eva/Documents/ITC/I5/ImageProcessing/mold_detection/shmold/data/sharp/valid/labels.cache... 99 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 99/99 346.9Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s0.2ss
#                    all         99        438      0.615      0.475      0.559      0.321      0.604      0.466      0.539      0.276
# Speed: 1.9ms preprocess, 9.7ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /home/eva/Documents/ITC/I5/ImageProcessing/mold_detection/shmold/notebook/runs/segment/val30
# --- Benchmark Results ---
# Precision (Quality): 0.6154
# Recall (Completeness): 0.4749
# mAP@50 (Overall Accuracy): 0.5588
# mAP@50-95 (Strict Accuracy): 0.3211
# Inference Speed: 9.69 ms per image
#
# --- Cleaning up GPU memory ---
# GPU memory cleared successfully!
